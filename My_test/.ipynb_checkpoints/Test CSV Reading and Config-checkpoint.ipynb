# %%
import pandas as pd

# %%
config = pd.read_csv('config.csv')

# %%
config
# Out:
#             gamename  threshold  Unnamed: 2
# 0             Amidar      130.0         NaN
# 1            Assault     1800.0         NaN
# 2            Asterix     1440.0         NaN
# 3          Asteroids     1570.0         NaN
# 4           Atlantis  1267410.0         NaN
# 5          BankHeist      225.0         NaN
# 6         BattleZone    16600.0         NaN
# 7          BeamRider    10000.0         NaN
# 8            Berzerk      100.0         NaN
# 9            Bowling       50.0         NaN
# 10            Boxing       49.8         NaN
# 11          Breakout        9.5         NaN
# 12         Centipede    15000.0         NaN
# 13    ChopperCommand     3710.0         NaN
# 14      CrazyClimber    26430.0         NaN
# 15       DemonAttack     1166.5         NaN
# 16        DoubleDunk        0.2         NaN
# 17            Enduro       95.0         NaN
# 18      FishingDerby       49.0         NaN
# 19           Freeway       31.0         NaN
# ...
